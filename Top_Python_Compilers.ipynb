# %% [markdown]
# <a href="https://colab.research.google.com/github/epythonlab/epythonlab/blob/master/Top_Python_Compilers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Top Python Compilers for Optimal Code Execution

# %% [markdown]
# ## Introduction to Compilers

# %% [markdown]
# - Python is a widely-used interpreted language known for its simplicity and flexibility.
# - However, interpreting code line by line can sometimes result in slower execution, especially for larger programs.
# - Python compilers offer a solution by converting high-level Python code into machine code for faster and more efficient execution.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Top Compilers

# %% [markdown]
# ### 1. CPython

# %% [markdown]
# - **CPython**: Default Python compiler written in C.
# - Compiles Python code into bytecode, interpreted by the Python virtual machine.
# - Highly portable and compatible with various platforms and Python libraries.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Sample Python code
def greet():
    print("Hello, world!")

# Bytecode generated by CPython
import dis
dis.dis(greet)
# Out:
#   3           0 LOAD_GLOBAL              0 (print)
#               2 LOAD_CONST               1 ('Hello, world!')
#               4 CALL_FUNCTION            1
#               6 POP_TOP
#               8 LOAD_CONST               0 (None)
#              10 RETURN_VALUE

# %% [markdown]
# ### 2. PyPy

# %% [markdown]
# - **PyPy**: Fast and efficient Python compiler written in Python itself.
# - Utilizes **just-in-time (JIT)** compilation for dynamic code compilation at runtime.
# -Offers better performance and memory management compared to CPython.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Sample Python code
def calculate():
    result = 0
    for i in range(1000000):
        result += i
    return result

# PyPy executes the code efficiently at runtime

# %% [markdown]
# ### 3.Cython

# %% [markdown]
# - **Cython**: Programming language superset of Python.
# - Compiles into C code for enhanced speed and efficiency.
# - Ideal for high-performance applications like scientific computing and machine learning.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Install using the following command

# %%
# !pip install Cython

# %% [markdown]
# To begin, you must load in the cython extension when working inside a jupyter notebook.

# %%
# %load_ext cython

# %%
# %%cython
# # Sample Cython code
# cpdef int square(int x):
#     return x * x
#
# # Cython translates the code into efficient C code
#
# print(square(4))
# Out:
# 16

# %% [markdown]
# ### 4. Numba

# %% [markdown]
# - **Numba**: **Just-in-time (JIT)** compiler for Python, designed for scientific computing.
# - Built on the LLVM(Low Level Virtual Machine) compiler infrastructure for optimized machine code generation.
# - Supports **NumPy** arrays and functions, facilitates easy parallelization of code.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Install numba using the following command

# %%
# !pip install numba

# %%
# Sample Numba code
import numpy as np
from numba import jit

@jit
def compute():
    a = np.random.rand(1000, 1000)
    b = np.random.rand(1000, 1000)
    return np.dot(a, b)

# Numba optimizes the code for efficient execution
compute()
# Out:
# <ipython-input-11-3852f5a7dfe2>:6: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def compute():
# array([[252.37964076, 260.84520403, 252.3027223 , ..., 245.97161863,
#         254.78951964, 259.86791191],
#        [240.45223644, 248.25044895, 243.11311546, ..., 235.7541757 ,
#         242.97527531, 252.25255627],
#        [245.92002037, 254.72956305, 251.8241506 , ..., 243.53457621,
#         253.55998952, 253.70308236],
#        ...,
#        [249.43078919, 252.11957053, 254.43282195, ..., 246.80405587,
#         249.47108604, 253.95124751],
#        [249.83195758, 260.83591873, 259.10850242, ..., 246.90405247,
#         251.59039696, 258.38338888],
#        [248.27208074, 258.16959935, 250.78982646, ..., 248.58804541,
#         249.73640717, 261.71170214]])

# %% [markdown]
# ### 5. Jython

# %% [markdown]
# - **Jython**: Python compiler written in Java.
# - Compiles Python code into Java bytecode for execution.
# - Compatible with Java libraries and packages, highly portable across platforms.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Sample Jython code
def greet():
    print("Hello, Jython!")

# Jython compiles Python code into Java bytecode for execution

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - Python compilers offer diverse capabilities catering to various project requirements.
# - Consider factors like speed, efficiency, compatibility, and platform support when selecting a Python compiler.
# - Choose the best compiler to optimize performance and streamline development.
